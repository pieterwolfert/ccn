# %% [markdown]
# # Practical Assignment 3

# %% [markdown]
# In this assignment a perceptron a two layer MLP and a three-layer MLP are trained and evaluated on the MNIST dataset. Moreover, two ConvNet architectures are trained and evaluated.The MNIST dataset (provided by Yann Lecun) consists of handwritten digits of which an example is shown in figure 1.
#
# The networks are trained for 50 epochs with a batch size of 32.

# %% [markdown]
# ![687474703a2f2f692e7974696d672e636f6d2f76692f3051493378675875422d512f687164656661756c742e6a7067.jpeg](attachment:687474703a2f2f692e7974696d672e636f6d2f76692f3051493378675875422d512f687164656661756c742e6a7067.jpeg)
#
# Figure 1: An example of the MNIST dataset
#
# #### Imports

# %%
import numpy as np
import chainer
from chainer import cuda, Function, gradient_check, report, training, utils, Variable
from chainer import datasets, iterators, optimizers, serializers
from chainer import Link, Chain, ChainList
import chainer.functions as F
import chainer.links as L
from chainer.training import extensions
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# #### Visualization function

# %% [markdown]
# The cell below implements the visualisation of the losses. "ggplot" is used to create fancier plots than the vanilla matplotlib plots. The y-axis displays the loss and the x-axis displays the epochs, with a step size of 5.

# %%
def visualizeLoss(ep_loss, test_loss, nr_epochs=50):
    matplotlib.style.use('ggplot')
    figure = plt.figure(figsize=(15,8))
    ax = figure.add_subplot(111)
    ax.set_xlabel('epoch')
    ax.set_ylabel('loss')
    xticks = np.arange(1, nr_epochs+1, 5)
    ax.set_xticks(xticks)  
    e_train, l_train = [point['epoch'] for point in ep_loss], [point['loss'] for point in ep_loss]
    e_test, l_test = [point['epoch'] for point in test_loss], [point['loss'] for point in test_loss]
    train, = plt.plot(e_train, l_train, 'b', label = 'train loss')
    test, = plt.plot(e_test, l_test, 'r', label = 'test loss')
    plt.legend([train, test], ['train loss', 'test loss'])
    plt.show()

# %% [markdown]
# ### Part 1 - training of 3 different neural networks

# %% [markdown]
# ####  Defining the network
# In the class below the structure of the N-layer network is defined. It consists of N linear layers. N is determined by the input parameter "n_layers". "n_out" represents the output of the layers, which is also equal to the number of units in each layer. A classifier is defined as a top wrapper on the model for accuracy evaluation and prediction.

# %%
class RNN(Chain):
    def __init__(self):
        super(RNN, self).__init__():
            with self.init_scope():
               self.lstm = L.LSTM(2,2) 
               self.linear = L.linear(2,1)
                
def create_data(n=3000):

    X = np.random.rand(n, 2).astype('float32')

    T = np.sum(X, 1)
    T = np.hstack([0, T[1:]]).astype('float32')
    T = T.reshape([n,1])

    return TupleDataset(X, T)


class Regressor(Chain):
    """
    
    Regressor chain on top of Neural Network chain 
    for accuracy evaluation and prediction
    
    """
    def __init__(self, predictor):
        super(Regressor, self).__init__()
        with self.init_scope():
            self.predictor = predictor
    
    def __call__(self, x, t):
        y = self.predictor(x)
        loss = F.softmax_cross_entropy(y, t)
        accuracy = F.accuracy(y, t)
        report({'loss': loss, 'accuracy': accuracy}, self)
        return loss

# %% [markdown]
# #### Training and test set creation

# %% [markdown]
# In the cell below, we retrieve the training and test data sets. Moreover, we set up a one layer, two layer and three layer network. All networks consist of layers of 10 units. We picked the Adam as optimizer instead of the more conventional SGD, since it tends to work better with fewer epochs.

# %%
# Retrieve train & test data      
train, test, dimension = get_mnist(n_dim=1)
# split test inputs and labels
inputs, labels = np.array([tup[0] for tup in test]), np.array([tup[1] for tup in test])

# Set up 1 layer model
model_sl = NLayerNetwork(10, 1)
classifier_sl = Classifier(model_sl)
optimizer_sl = optimizers.Adam()
optimizer_sl.setup(classifier_sl)

#Set up 2 layer model
model_mlp = NLayerNetwork(10, 2)
classifier_mlp = Classifier(model_mlp)
optimizer_mlp = optimizers.Adam()
optimizer_mlp.setup(classifier_mlp)

#Set up 3 layer model
model_tl = NLayerNetwork(10, 3)
classifier_tl = Classifier(model_tl)
optimizer_tl = optimizers.Adam()
optimizer_tl.setup(classifier_tl)

# %% [markdown]
# #### Implement the training & test loop

# %% [markdown]
# In the cell below, we implemented the training & test loops. We train in batches of 32 samples for 50 epochs. For each batch we compute the loss and backpropagate the error. We store the loss per batch. After each epoch, we compute the loss on the test data and the average loss on the training batches and store these quantities and return them at the end.

# %%
def training(train, test, inputs, labels, classifier, optimizer, nr_of_epochs = 50):
    iterator = RandomIterator(train,32)
    av_loss = []
    ep_loss = []
    test_loss = []
    for epoch in range(1,nr_of_epochs+1):
         for batch in iterator:
            sources,targets = batch[0], batch[1]
            classifier.cleargrads()
            loss = F.sum(classifier(sources, targets))
            loss.backward()
            av_loss.append(loss.data)    
            optimizer.update()
         loss =  sum(av_loss) / len(av_loss)
         ep_loss.append({'epoch': epoch, 'loss': loss})
         # test classifier
         loss = F.sum(classifier(inputs, labels))
         test_loss.append({'epoch': epoch, 'loss': loss.data})
         av_loss = []
    return ep_loss, test_loss

# %% [markdown]
# #### Training for 1 layer neural network

# %%
ep_loss, test_loss = training(train, test, inputs, labels, classifier_sl, optimizer_sl)
visualizeLoss(ep_loss, test_loss)

# %% [markdown]
# #### Training 2 layer neural network

# %%
ep_loss, test_loss = training(train, test, inputs, labels, classifier_mlp, optimizer_mlp)
visualizeLoss(ep_loss, test_loss)

# %% [markdown]
# #### Training 3 layer neural network

# %%
ep_loss, test_loss = training(train, test, inputs, labels, classifier_tl, optimizer_tl)
visualizeLoss(ep_loss, test_loss)

# %% [markdown]
# ### Conclusions part 1

# %% [markdown]
# For all networks we see that the test loss convergers at around 20 25 epochs, while the train loss keeps decreasing.
# In all three networks we see that the train loss is lower than the test loss, which is to be expected. However we see that for N = 3 and N = 2 the generalization error is higher than for the one-layer network and the loss is lower. We conclude that for this problem the one-layer generalizes better than the multi-layer networks and has a better performance on this problem.

# %% [markdown]
# ### Part 2 - Convolutional Neural Network

# %% [markdown]
# Implementation of a convolutional neural network consisting of 1 convolutional layer, 1 max pooling layer and 1 fully connected layer.
#
# Convolutional layer has 5 outputs, kernel size of 5, stride of 1 and padding of 0

# %%
class ConvNet(Chain):
    """
    
    Implementation of a Convolutional Network 
    
    """
    def __init__(self):
        super(ConvNet, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(in_channels=None, out_channels=5, ksize=5, stride=1, pad=0)
            self.l1 = L.Linear(None, 10)
        
    def __call__(self, x):
        h = F.relu(self.conv1(x))
        h = F.max_pooling_2d(h, 2)
        output = F.softmax(self.l1(h))
        return output

# %% [markdown]
# #### Model creation

# %%
model_conv = ConvNet()
classifier_conv = Classifier(model_conv)
optimizer_conv = optimizers.Adam()
optimizer_conv.setup(classifier_conv)

# %% [markdown]
# #### Model training

# %%
train, test, dimension = get_mnist(n_dim=3)
inputs, labels = np.array([tup[0] for tup in test]), np.array([tup[1] for tup in test])
# Out:
# 3

# %%
ep_loss, test_loss = training(train, test, inputs, labels, classifier_conv, optimizer_conv)
visualizeLoss(ep_loss, test_loss)

# %% [markdown]
# ### Conclusions part 2

# %% [markdown]
# For the convolutional neural network we see that both the train and test loss converge after roughly 35 epochs. We also see that train loss is significantly lower than the test loss which indicates overfitting. The loss on the validation data is not considerably lower than in the previous networks, which indicates that this convolution network does not perform better on this problem.

# %% [markdown]
# ### Part 3 Explain in which ways convolution is biologically plausible and biologically implausible

# %% [markdown]
# Convolution is biologically plausible by the fact that it creates so called feature maps that represent a specific feature in the visual area. This is in accordance with how the visual system works, in which neurons are tuned to specific features in the visual field. Additionally, in the dominant CNN architectures simple Linear-Non-linear transformations are repeated over many layers that together create a hierarchy of more complex internal representations, which is in accordance with the hierarchillay organized visual system. However, there are several arguments which support the biological implausibility  of CNN's. Firstly, in current CNN implementations weights are shared in convolution layers for efficiency purposes, which is likely not the case in the visual system. Furthermore, current dominant implementations do not have recurrent connections which do occur in the visual system. Moreover, biological networks make use of spikes in order to communicate and therefore take into account temporal information. Current CNN architectures do not use spikes and do not take into account temporal information.

# %% [markdown]
# ### Part 4 Model changes

# %% [markdown]
# In order to improve the network we have made the following modifications. We have added an extra convolution layer followed by a max pooling layer. Next, we have added a dropout layer. We again use A for optimization.

# %%
class ConvNetImproved(Chain):
    """
    
    Implementation of a Convolutional Network 
    
    """
    def __init__(self):
        super(ConvNetImproved, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(in_channels=None, out_channels=5, ksize=5, stride=1, pad=0)
            self.conv2 = L.Convolution2D(in_channels=5, out_channels=16, ksize=5, stride=1, pad=0)
            self.l1 = L.Linear(None, 200)
            self.l2 = L.Linear(200, 10)
        
    def __call__(self, x):
        h = F.relu(self.conv1(x))
        h = F.max_pooling_2d(h, 2)
        h = F.relu(self.conv2(h))
        h = F.max_pooling_2d(h, 2)
        h = F.dropout(F.relu(self.l1(h)))
        output = F.softmax(self.l2(h))
        return output

# %%
model_conv2 = ConvNetImproved()
classifier_conv2 = Classifier(model_conv2)
optimizer_conv2 = optimizers.Adam()
optimizer_conv2.setup(classifier_conv2)

# %%
ep_loss, test_loss = training(train, test, inputs, labels, classifier_conv2, optimizer_conv2)
visualizeLoss(ep_loss, test_loss)

# %% [markdown]
# ### Conclusions Part 4

# %% [markdown]
# From the plot we see that the both the train and test converge around epoch 45. While the test loss is similar to the original convnet architecture, the train loss is higher. This suggests that the new architecture has less overfitting issues than the original architecture.
